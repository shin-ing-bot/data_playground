# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-ing-bot/hello_Test/blob/main/weather_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

try:
    df = pd.read_csv("/content/OBS_ASOS_TIM_20251030122242.xls")
    print("File loaded successfully as CSV.")
    display(df.head())
except Exception as e:
    print(f"Failed to load as CSV: {e}")
# Out:
# Failed to load as CSV: 'utf-8' codec can't decode byte 0xc1 in position 0: invalid start byte

# %%
correlation_matrix = df.corr(numeric_only=True)
display(correlation_matrix)
# Out:
#              지점    일조(hr)  일조 QC플래그  일사(MJ/m2)  일사 QC플래그  전운량(10분위)  \
# 지점          NaN       NaN       NaN        NaN       NaN        NaN
# 일조(hr)      NaN  1.000000       NaN   0.720247       NaN  -0.833207
# 일조 QC플래그    NaN       NaN       NaN        NaN       NaN        NaN
# 일사(MJ/m2)   NaN  0.720247       NaN   1.000000       NaN  -0.393762
# 일사 QC플래그    NaN       NaN       NaN        NaN       NaN        NaN
# 전운량(10분위)   NaN -0.833207       NaN  -0.393762       NaN   1.000000
# 중하층운량(10분위) NaN -0.778111       NaN  -0.350163       NaN   0.991650
# 최저운고(100m ) NaN  0.722296       NaN   0.826098       NaN  -0.438207
#
#              중하층운량(10분위)  최저운고(100m )
# 지점                   NaN          NaN
# 일조(hr)         -0.778111     0.722296
# 일조 QC플래그             NaN          NaN
# 일사(MJ/m2)      -0.350163     0.826098
# 일사 QC플래그             NaN          NaN
# 전운량(10분위)       0.991650    -0.438207
# 중하층운량(10분위)     1.000000    -0.391828
# 최저운고(100m )    -0.391828     1.000000

# %%
df = pd.read_csv("/content/OBS_ASOS_TIM_20251030122242.xls", encoding='cp949', sep='\t')
print("File loaded successfully as tab-separated CSV with cp949 encoding.")
display(df.head())
# Out:
# File loaded successfully as tab-separated CSV with cp949 encoding.
#     지점 지점명                일시  일조(hr)  일조 QC플래그  일사(MJ/m2)  일사 QC플래그  \
# 0  184  제주  2025-10-28 01:00     NaN       9.0        NaN       9.0
# 1  184  제주  2025-10-28 02:00     NaN       9.0        NaN       9.0
# 2  184  제주  2025-10-28 03:00     NaN       9.0        NaN       9.0
# 3  184  제주  2025-10-28 04:00     NaN       9.0        NaN       9.0
# 4  184  제주  2025-10-28 05:00     NaN       9.0        NaN       9.0
#
#    전운량(10분위)  중하층운량(10분위) 운형(운형약어)  최저운고(100m )
# 0          7            6      NaN         15.0
# 1         10            8      NaN         11.0
# 2          9            9       Sc         13.0
# 3          8            8       Sc         12.0
# 4          8            8       Sc         13.0

# %%
display(df.head())
display(df.info())
display(df.describe(include='all'))
# Out:
#     지점 지점명                일시  일조(hr)  일조 QC플래그  일사(MJ/m2)  일사 QC플래그  \
# 0  184  제주  2025-10-28 01:00     NaN       9.0        NaN       9.0
# 1  184  제주  2025-10-28 02:00     NaN       9.0        NaN       9.0
# 2  184  제주  2025-10-28 03:00     NaN       9.0        NaN       9.0
# 3  184  제주  2025-10-28 04:00     NaN       9.0        NaN       9.0
# 4  184  제주  2025-10-28 05:00     NaN       9.0        NaN       9.0
#
#    전운량(10분위)  중하층운량(10분위) 운형(운형약어)  최저운고(100m )
# 0          7            6      NaN         15.0
# 1         10            8      NaN         11.0
# 2          9            9       Sc         13.0
# 3          8            8       Sc         12.0
# 4          8            8       Sc         13.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   지점           24 non-null     int64
# ...

# %%
import matplotlib.pyplot as plt

df['일시'] = pd.to_datetime(df['일시'])
df.set_index('일시', inplace=True)

plt.figure(figsize=(12, 6))
plt.plot(df.index, df['일조(hr)'], label='일조(hr)', marker='o')
plt.plot(df.index, df['일사(MJ/m2)'], label='일사(MJ/m2)', marker='x')

plt.title('시간 경과에 따른 일조 및 일사 변화')
plt.xlabel('일시')
plt.ylabel('값')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1608121117.py:15: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-1608121117.py:15: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-1608121117.py:15: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-1608121117.py:15: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-1608121117.py:15: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-1608121117.py:15: UserWarning: Glyph 44284 (\N{HANGUL SYLLABLE GWA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

fm.fontManager.addfont('/usr/share/fonts/truetype/nanum/NanumGothic.ttf')
plt.rc('font', family='NanumGothic')
plt.rc('axes', unicode_minus=False)

plt.figure(figsize=(12, 6))
plt.plot(df.index, df['일조(hr)'], label='일조(hr)', marker='o')
plt.plot(df.index, df['일사(MJ/m2)'], label='일사(MJ/m2)', marker='x')

plt.title('시간 경과에 따른 일조 및 일사 변화')
plt.xlabel('일시')
plt.ylabel('값')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 0s (23.5 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['일조(hr)'], label='일조(hr)', marker='o')
plt.plot(df.index, df['일사(MJ/m2)'], label='일사(MJ/m2)', marker='x')

plt.title('시간 경과에 따른 일조 및 일사 변화')
plt.xlabel('일시')
plt.ylabel('값')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))

# Plot '일조(hr)' and '일사(MJ/m2)' on the primary y-axis
plt.plot(df.index, df['일조(hr)'], label='일조(hr)', marker='o')
plt.plot(df.index, df['일사(MJ/m2)'], label='일사(MJ/m2)', marker='x')
plt.ylabel('일조(hr) / 일사(MJ/m2)')

# Create a secondary y-axis for '전운량(10분위)' and '중하층운량(10분위)'
ax2 = plt.twinx()
ax2.plot(df.index, df['전운량(10분위)'], label='전운량(10분위)', marker='s', color='green')
ax2.plot(df.index, df['중하층운량(10분위)'], label='중하층운량(10분위)', marker='^', color='red')
ax2.set_ylabel('운량(10분위)')

plt.title('시간 경과에 따른 일조, 일사, 운량 변화')
plt.xlabel('일시')

# Combine legends from both axes
lines, labels = plt.gca().get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left')

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap=plt.cm.RdBu, linewidths=0.1, vmax=1.0, annot=True)
plt.title('상관 행렬 히트맵')
plt.show()

# %% [markdown]
# # Task
# Combine the data from "/content/채소생산량_조미채소__20251106104707.csv" with the weather data, and then forecast the '일조(hr)' (sunshine hours) for the next 3 years.

# %% [markdown]
# ## Load vegetable production data
#
# ### Subtask:
# Load the vegetable production data from `/content/채소생산량_조미채소__20251106104707.csv` into a DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the vegetable production data into a pandas DataFrame.

# %%
df_vegetable = pd.read_csv('/content/채소생산량_조미채소__20251106104707.csv')
display(df_vegetable.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2206657062.py in <cell line: 0>()
# ----> 1 df_vegetable = pd.read_csv('/content/채소생산량_조미채소__20251106104707.csv')
#       2 display(df_vegetable.head())
#
# NameError: name 'pd' is not defined

# %% [markdown]
# **Reasoning**:
# The previous command failed because pandas was not imported. I need to import pandas first and then load the data.

# %%
import pandas as pd

df_vegetable = pd.read_csv('/content/채소생산량_조미채소__20251106104707.csv')
display(df_vegetable.head())
# Out:
#     시도별          2025        2025.1      2025.2      2025.3       2025.4  \
# 0   시도별  조미채소:면적 (ha)  조미채소:생산량 (톤)  고추:면적 (ha)  고추:생산량 (톤)  건고추:면적 (ha)
# 1  충청북도             -             -           -           -            -
# 2  충청남도             -             -           -           -            -
# 3   제주도             -             -           -           -            -
# 4  전라북도             -             -           -           -            -
#
#               2025.5       2025.6       2025.7             2025.8  ...  \
# 0  건고추:10a당 생산량 (kg)  건고추:생산량 (톤)  풋고추:면적 (ha)  풋고추:10a당 생산량 (kg)  ...
# 1                  -            -            -                  -  ...
# 2                  -            -            -                  -  ...
# 3                  -            -            -                  -  ...
# 4                  -            -            -                  -  ...
#
#         2025.35     2025.36           2025.37     2025.38     2025.39  \
# ...

# %% [markdown]
# ## Inspect vegetable production data
#
# ### Subtask:
# Inspect the vegetable production DataFrame to understand its structure and content.

# %% [markdown]
# **Reasoning**:
# Display the head, info, and descriptive statistics of the `df_vegetable` DataFrame to understand its structure, data types, and content as requested by the instructions.

# %%
display(df_vegetable.head())
display(df_vegetable.info())
display(df_vegetable.describe(include='all'))
# Out:
#     시도별          2025        2025.1      2025.2      2025.3       2025.4  \
# 0   시도별  조미채소:면적 (ha)  조미채소:생산량 (톤)  고추:면적 (ha)  고추:생산량 (톤)  건고추:면적 (ha)
# 1  충청북도             -             -           -           -            -
# 2  충청남도             -             -           -           -            -
# 3   제주도             -             -           -           -            -
# 4  전라북도             -             -           -           -            -
#
#               2025.5       2025.6       2025.7             2025.8  ...  \
# 0  건고추:10a당 생산량 (kg)  건고추:생산량 (톤)  풋고추:면적 (ha)  풋고추:10a당 생산량 (kg)  ...
# 1                  -            -            -                  -  ...
# 2                  -            -            -                  -  ...
# 3                  -            -            -                  -  ...
# 4                  -            -            -                  -  ...
#
#         2025.35     2025.36           2025.37     2025.38     2025.39  \
# ...

# %% [markdown]
# ## Merge dataframes
#
# ### Subtask:
# Merge the weather DataFrame (df) and the vegetable production DataFrame on a common column, likely a date or time column, after ensuring consistent data types and formats.

# %% [markdown]
# **Reasoning**:
# Identify and process the time/date columns in both dataframes for merging.

# %%
# Examine the time/date columns in both dataframes
print("df time column info:")
display(df.index.info())
print("\ndf_vegetable time column info:")
display(df_vegetable.info())

# Based on the inspection, '일시' in df is already a datetime index.
# In df_vegetable, the relevant time information seems to be embedded in the column headers like '2025'.
# However, the request is to forecast '일조(hr)' from the weather data, which is time-series data.
# The vegetable data seems to be aggregated by year and potentially by province ('시도별').
# Merging these two dataframes directly on a common time column might not be straightforward or meaningful
# as the granularity of time is different (hourly for weather, yearly for vegetable production).
# It is not clear how to merge hourly weather data with yearly vegetable production data to forecast '일조(hr)'.
# The subtask is to merge the dataframes, but a direct merge on time doesn't seem appropriate for the overall goal.
# I will proceed with a merge attempt based on the year, but this might not be the intended approach given the forecasting task.

# Extract the year from the datetime index in df
df['Year'] = df.index.year

# Clean df_vegetable to use the first row as headers and remove the first row
df_vegetable.columns = df_vegetable.iloc[0]
df_vegetable = df_vegetable[1:].reset_index(drop=True)

# Melt df_vegetable to long format to easily extract year and value
df_vegetable_melted = df_vegetable.melt(id_vars=['시도별'], var_name='Variable_Year', value_name='Value')

# Extract Year from the melted dataframe
df_vegetable_melted['Year'] = df_vegetable_melted['Variable_Year'].str.extract(r'(\d{4})').astype(int)

# Merge the two dataframes on the 'Year' column. Using an outer merge to keep all data.
merged_df = pd.merge(df, df_vegetable_melted, on='Year', how='outer')

# Display the head of the merged DataFrame
display(merged_df.head())
# Out:
# df time column info:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1344962965.py in <cell line: 0>()
#       1 # Examine the time/date columns in both dataframes
#       2 print("df time column info:")
# ----> 3 display(df.index.info())
#       4 print("\ndf_vegetable time column info:")
#       5 display(df_vegetable.info())
#
# NameError: name 'df' is not defined

# %% [markdown]
# **Reasoning**:
# The previous attempt failed because the `df` dataframe was not available in the current kernel session. The `df` dataframe needs to be recreated by loading the weather data again.

# %%
import pandas as pd

# Load the weather data again as df was not available
try:
    df = pd.read_csv("/content/OBS_ASOS_TIM_20251030122242.xls", encoding='cp949', sep='\t')
    print("Weather file loaded successfully.")
except Exception as e:
    print(f"Failed to load weather file: {e}")

# Convert '일시' to datetime and set as index
df['일시'] = pd.to_datetime(df['일시'])
df.set_index('일시', inplace=True)

# Examine the time/date columns in both dataframes
print("\ndf time column info after loading:")
display(df.index.info())
print("\ndf_vegetable time column info:")
display(df_vegetable.info())

# Based on the inspection, '일시' in df is a datetime index.
# In df_vegetable, the relevant time information seems to be embedded in the column headers like '2025'.
# However, the request is to forecast '일조(hr)' from the weather data, which is time-series data.
# The vegetable data seems to be aggregated by year and potentially by province ('시도별').
# Merging these two dataframes directly on a common time column might not be straightforward or meaningful
# as the granularity of time is different (hourly for weather, yearly for vegetable production).
# It is not clear how to merge hourly weather data with yearly vegetable production data to forecast '일조(hr)'.
# The subtask is to merge the dataframes, but a direct merge on time doesn't seem appropriate for the overall goal.
# I will proceed with a merge attempt based on the year, but this might not be the intended approach given the forecasting task.

# Extract the year from the datetime index in df
df['Year'] = df.index.year

# Clean df_vegetable to use the first row as headers and remove the first row
df_vegetable.columns = df_vegetable.iloc[0]
df_vegetable = df_vegetable[1:].reset_index(drop=True)

# Melt df_vegetable to long format to easily extract year and value
df_vegetable_melted = df_vegetable.melt(id_vars=['시도별'], var_name='Variable_Year', value_name='Value')

# Extract Year from the melted dataframe
df_vegetable_melted['Year'] = df_vegetable_melted['Variable_Year'].str.extract(r'(\d{4})').astype(int)

# Merge the two dataframes on the 'Year' column. Using an outer merge to keep all data.
merged_df = pd.merge(df, df_vegetable_melted, on='Year', how='outer')

# Display the head of the merged DataFrame
display(merged_df.head())
# Out:
# Failed to load weather file: [Errno 2] No such file or directory: '/content/OBS_ASOS_TIM_20251030122242.xls'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2064497617.py in <cell line: 0>()
#       9
#      10 # Convert '일시' to datetime and set as index
# ---> 11 df['일시'] = pd.to_datetime(df['일시'])
#      12 df.set_index('일시', inplace=True)
#      13
#
# NameError: name 'df' is not defined

# %% [markdown]
# **Reasoning**:
# The previous attempt failed because the weather file was not found at the specified path. I need to check the available files and use the correct file name for the weather data.

# %%
import pandas as pd

# Check available files
import os
print(os.listdir('/content'))

# Assuming the weather file is now available with a different name, try loading it with the correct name.
# From the available files, 'OBS_ASOS_TIM_20251030122242.xls' is not present.
# Let's assume the weather data is in a file that was previously loaded and used,
# likely associated with the correlation matrix calculation and the plots.
# Looking at the history, the file '/content/OBS_ASOS_TIM_20251030122242.xls' was attempted to be loaded
# and then successfully loaded with encoding='cp949' and sep='\t'.
# However, the file is now reported as not found.
# It's possible the file name or location has changed or was temporary.
# Since I cannot proceed without the weather data, I will have to report failure for this subtask.
# If a different file contains the weather data, I would need to know its name.
# As I cannot ask for clarification, I must assume the required file is not available.

# Since the weather file is not accessible, I cannot proceed with merging.
# I will indicate failure for this subtask.
# Out:
# ['.config', '채소생산량_조미채소__20251106104707.csv', 'sample_data']

# %% [markdown]
# ## Merge dataframes retry 1
#
# ### Subtask:
# Retry merging the weather DataFrame (df) and the vegetable production DataFrame on a common column, likely a date or time column, after ensuring consistent data types and formats. The previous attempt failed because the weather data file was not found. This retry assumes the weather data was successfully loaded into a DataFrame named `df` in a previous step, although the exact loading code is not visible in the provided history. If `df` is still not available, this subtask will fail again.

# %% [markdown]
# **Reasoning**:
# The previous attempt to merge failed because the weather data file was not found. Looking at the history, cell `8fa5aaa1` successfully loaded the weather data into `df`. I need to rerun that cell to make `df` available again, then proceed with merging the two dataframes.

# %%
df = pd.read_csv("/content/OBS_ASOS_TIM_20251030122242.xls", encoding='cp949', sep='\t')
print("File loaded successfully as tab-separated CSV with cp949 encoding.")
display(df.head())

# Inspect df to identify the date/time column
display(df.info())

# Inspect df_vegetable to identify the date/time column or a column to transform
display(df_vegetable.head())
display(df_vegetable.info())

# Based on inspection, '일시' in df is the time column.
# In df_vegetable, the columns represent years, and the first row contains the specific metric and year.
# The '시도별' column seems to represent the location, which is '제주도' in the example.
# The weather data is for '제주' (Jejudo).
# It looks like df_vegetable is aggregated by year and region, while df is hourly weather data for a specific location.
# Merging directly on a date/time column will be difficult due to the different granularities.
# I need to decide on a strategy for merging or relating these two datasets.
# Given the request is to forecast '일조(hr)' for the next 3 years, and df_vegetable has data for 2025,
# it seems the goal might be to relate weather patterns to vegetable production.
# However, the current subtask is only to merge the dataframes.
# Since a direct merge on date/time is not straightforward due to granularity and structure differences,
# and there is no clear common key other than potentially year and location (which is only '제주' in df),
# I will attempt to aggregate the weather data by year to potentially merge with df_vegetable by year and location.
# First, I need to extract the year from the '일시' column in df.

df['일시'] = pd.to_datetime(df['일시'])
df['Year'] = df['일시'].dt.year

# Now, aggregate df by Year and potentially location if there were more locations in df.
# Since df only has data for '제주', I'll aggregate by year and calculate the mean '일조(hr)'.
df_agg_weather = df.groupby(df['Year'])['일조(hr)'].mean().reset_index()
df_agg_weather['지점명'] = '제주' # Add location for potential merging

display(df_agg_weather.head())

# Now prepare df_vegetable for merging. The years are in the column headers and the first row.
# I need to reshape df_vegetable to have years as a column.
# Also, filter df_vegetable to only include '제주도' to match the weather data location.

# Use the first row as column names and drop it.
df_vegetable.columns = df_vegetable.iloc[0]
df_vegetable = df_vegetable.drop(0).reset_index(drop=True)

# Filter for '제주도'
df_vegetable_jeju = df_vegetable[df_vegetable['시도별'] == '제주도'].copy()

# Melt the DataFrame to have years as a column.
# Identify the year columns - assuming they are all columns except '시도별'.
year_cols = [col for col in df_vegetable_jeju.columns if col != '시도별']
df_vegetable_melted = df_vegetable_jeju.melt(id_vars=['시도별'], value_vars=year_cols, var_name='Metric_Year', value_name='Value')

# Extract Year from 'Metric_Year' and the Metric name.
# Assuming the format is "Metric:SubMetric (Unit):Year" or similar, and the year is the last part after the last colon or space.
# Let's refine this based on the actual column names after using the first row as header.
# The column names are like '조미채소:면적 (ha)', '조미채소:생산량 (톤)', '고추:면적 (ha)', '고추:생산량 (톤)', etc., followed by the year '2025'.
# The first row was "시도별 2025 2025.1 2025.2 ...", and the second row had "시도별 조미채소:면적 (ha) 조미채소:생산량 (톤) 고추:면적 (ha) ... 마늘:생산량 (톤)".
# So, after setting the first row as header and dropping it, the columns are the values from the first row ('2025', '2025.1', etc.)
# and the data rows contain the actual metric names in the first column. This is not the expected structure for melting.

# Let's re-examine the structure of df_vegetable after setting the header.
# The first column is '시도별', and the rest of the columns are named '2025', '2025.1', etc.
# The *values* in the DataFrame body are the metric names and the actual values.
# This structure is not suitable for a simple melt to get years as a column.

# A better approach might be to use the original df_vegetable and fix the column headers first,
# combining the year from the first row with the metric from the second row.

# Let's reload df_vegetable to get the original structure back.
df_vegetable = pd.read_csv('/content/채소생산량_조미채소__20251106104707.csv')

# Combine the first two rows to create meaningful headers.
# The first row contains the year information in columns 1 onwards.
# The second row contains the metric names in columns 1 onwards.
# The first column is '시도별' in both rows and should remain as is.

new_columns = [df_vegetable.iloc[0, 0]] # Start with '시도별'
for i in range(1, df_vegetable.shape[1]):
    year_info = str(df_vegetable.iloc[0, i]).strip()
    metric_info = str(df_vegetable.iloc[1, i]).strip()
    new_columns.append(f"{metric_info}_{year_info}")

df_vegetable.columns = new_columns

# Drop the original header rows (row 0 and 1).
df_vegetable = df_vegetable.drop([0, 1]).reset_index(drop=True)

display(df_vegetable.head())
display(df_vegetable.info())

# Now filter for '제주도'.
df_vegetable_jeju = df_vegetable[df_vegetable['시도별'] == '제주도'].copy()

# The weather data is for '제주'. Let's ensure the location names match for merging.
df_agg_weather['지점명'] = '제주도'

# Now, df_vegetable_jeju has columns like '조미채소:면적 (ha)_2025', '고추:생산량 (톤)_2025', etc.
# df_agg_weather has 'Year' and '일조(hr)' (mean) and '지점명'.
# To merge, I need to get the year as a separate column in df_vegetable_jeju and potentially melt it.

# Let's melt df_vegetable_jeju to have columns for 'Metric', 'Year', and 'Value'.
# Identify value columns (all except '시도별').
value_vars = [col for col in df_vegetable_jeju.columns if col != '시도별']

df_vegetable_melted = df_vegetable_jeju.melt(id_vars=['시도별'], value_vars=value_vars, var_name='Metric_Year', value_name='Value')

# Extract Metric and Year from 'Metric_Year'.
# Assuming the format is "MetricName_Year".
df_vegetable_melted['Metric'] = df_vegetable_melted['Metric_Year'].apply(lambda x: '_'.join(x.split('_')[:-1]))
df_vegetable_melted['Year'] = df_vegetable_melted['Metric_Year'].apply(lambda x: x.split('_')[-1])

# Convert 'Year' to integer type for merging.
df_vegetable_melted['Year'] = pd.to_numeric(df_vegetable_melted['Year'], errors='coerce')

# Drop the original 'Metric_Year' column as it's no longer needed.
df_vegetable_melted = df_vegetable_melted.drop(columns=['Metric_Year'])

# Convert 'Value' to numeric, coercing errors to NaN.
df_vegetable_melted['Value'] = pd.to_numeric(df_vegetable_melted['Value'], errors='coerce')

display(df_vegetable_melted.head())
display(df_vegetable_melted.info())

# Now merge df_agg_weather and df_vegetable_melted.
# We can merge on 'Year' and '시도별'/'지점명'.
# Since df_vegetable_melted has multiple rows per year and location (for different metrics),
# and df_agg_weather has one row per year and location (for mean 일조),
# a merge will repeat the weather data for each vegetable metric for that year and location. This seems acceptable for now.

merged_df = pd.merge(df_agg_weather, df_vegetable_melted, on=['Year', '지점명'], how='left')

display(merged_df.head())
display(merged_df.info())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2791772906.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("/content/OBS_ASOS_TIM_20251030122242.xls", encoding='cp949', sep='\t')
#       2 print("File loaded successfully as tab-separated CSV with cp949 encoding.")
#       3 display(df.head())
#       4
#       5 # Inspect df to identify the date/time column
#
# ...

# %% [markdown]
# ## Merge dataframes retry 2
#
# ### Subtask:
# Retry merging the weather DataFrame (df) and the vegetable production DataFrame on a common column, likely a date or time column, after ensuring consistent data types and formats. The previous attempts failed because the weather data file was not found. This retry will explicitly load the weather data using the code that was previously successful in the kernel history before attempting the merge.

# %% [markdown]
# **Reasoning**:
# The previous attempts to merge failed because the weather data was not loaded correctly. The provided history shows that cell `8fa5aaa1` successfully loaded the weather data. I will explicitly use the code from that cell to load the weather data first, then proceed with the data processing and merging steps as outlined in the instructions. I will combine multiple steps into a single code block for efficiency.

# %%
# Step 1: Load the weather data using the successful code from history
df = pd.read_csv("/content/OBS_ASOS_TIM_20251030122242.xls", encoding='cp949', sep='\t')
print("Weather file loaded successfully as tab-separated CSV with cp949 encoding.")

# Step 2: Convert the '일시' column in the df DataFrame to datetime objects.
df['일시'] = pd.to_datetime(df['일시'])

# Step 3: Extract the year from the '일시' column and store it in a new column named 'Year' in df.
df['Year'] = df['일시'].dt.year

# Step 4: Aggregate df by 'Year' and calculate the mean of '일조(hr)', storing the result in a new DataFrame df_agg_weather.
df_agg_weather = df.groupby('Year')['일조(hr)'].mean().reset_index()

# Step 5: Add a '지점명' column to df_agg_weather and set its value to '제주도' to match the location in df_vegetable.
df_agg_weather['지점명'] = '제주도'
print("\nAggregated weather data:")
display(df_agg_weather.head())

# Step 6: Reload df_vegetable from /content/채소생산량_조미채소__20251106104707.csv to ensure its original structure.
df_vegetable = pd.read_csv('/content/채소생산량_조미채소__20251106104707.csv')
print("\nVegetable production file reloaded.")

# Step 7: Combine the first two rows of df_vegetable to create meaningful column headers.
new_columns = [df_vegetable.iloc[0, 0]] # Start with '시도별'
for i in range(1, df_vegetable.shape[1]):
    year_info = str(df_vegetable.iloc[0, i]).strip()
    metric_info = str(df_vegetable.iloc[1, i]).strip()
    new_columns.append(f"{metric_info}_{year_info}")
df_vegetable.columns = new_columns

# Step 8: Drop the original header rows (row 0 and 1) from df_vegetable.
df_vegetable = df_vegetable.drop([0, 1]).reset_index(drop=True)
print("\nVegetable production data with updated headers:")
display(df_vegetable.head())

# Step 9: Filter df_vegetable to include only rows where the '시도별' column is '제주도', storing the result in df_vegetable_jeju.
df_vegetable_jeju = df_vegetable[df_vegetable['시도별'] == '제주도'].copy()
print("\nFiltered vegetable data for Jeju-do:")
display(df_vegetable_jeju.head())

# Step 10: Melt the df_vegetable_jeju DataFrame to transform the metric-year columns into rows.
value_vars = [col for col in df_vegetable_jeju.columns if col != '시도별']
df_vegetable_melted = df_vegetable_jeju.melt(id_vars=['시도별'], value_vars=value_vars, var_name='Metric_Year', value_name='Value')

# Step 11: Extract the Metric and Year from the 'Metric_Year' column.
df_vegetable_melted['Metric'] = df_vegetable_melted['Metric_Year'].apply(lambda x: '_'.join(x.split('_')[:-1]))
df_vegetable_melted['Year'] = df_vegetable_melted['Metric_Year'].apply(lambda x: x.split('_')[-1])

# Drop the original 'Metric_Year' column.
df_vegetable_melted = df_vegetable_melted.drop(columns=['Metric_Year'])

# Step 12: Convert the 'Year' column in the melted vegetable DataFrame to numeric, coercing errors.
df_vegetable_melted['Year'] = pd.to_numeric(df_vegetable_melted['Year'], errors='coerce')

# Step 13: Convert the 'Value' column in the melted vegetable DataFrame to numeric, coercing errors.
df_vegetable_melted['Value'] = pd.to_numeric(df_vegetable_melted['Value'], errors='coerce')
print("\nMelted vegetable data:")
display(df_vegetable_melted.head())
display(df_vegetable_melted.info())

# Step 14: Merge df_agg_weather and the melted vegetable DataFrame (df_vegetable_melted) on the 'Year' and '지점명' columns using a left merge.
merged_df = pd.merge(df_agg_weather, df_vegetable_melted, on=['Year', '지점명'], how='left')

# Step 15: Display the head and info of the resulting merged DataFrame.
print("\nMerged DataFrame:")
display(merged_df.head())
display(merged_df.info())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3846112844.py in <cell line: 0>()
#       1 # Step 1: Load the weather data using the successful code from history
# ----> 2 df = pd.read_csv("/content/OBS_ASOS_TIM_20251030122242.xls", encoding='cp949', sep='\t')
#       3 print("Weather file loaded successfully as tab-separated CSV with cp949 encoding.")
#       4
#       5 # Step 2: Convert the '일시' column in the df DataFrame to datetime objects.
#
# ...

# %% [markdown]
# **Reasoning**:
# The attempt to load the weather data failed again because the file was not found at the specified path. I need to check the available files in the `/content` directory to confirm the file name and location.

# %%
import os
print(os.listdir('/content'))
# Out:
# ['.config', '채소생산량_조미채소__20251106104707.csv', 'sample_data']

# %% [markdown]
# ## Merge dataframes retry 3
#
# ### Subtask:
# Retry merging the weather DataFrame (df) and the vegetable production DataFrame on a common column, likely a date or time column, after ensuring consistent data types and formats. The previous attempts failed because the weather data file was not found. This retry acknowledges that the file might be permanently unavailable and will attempt to proceed with the analysis on the vegetable production data alone, focusing on any time-series aspects within that dataset, or will report failure if merging is strictly necessary and the weather data cannot be obtained.

# %% [markdown]
# **Reasoning**:
# Acknowledge the unavailability of the weather data, examine the vegetable production DataFrame for time-series aspects, and report failure if the weather data is essential and unavailable.

# %%
# 1. Acknowledge that the weather data file 'OBS_ASOS_TIM_20251030122242.xls' was not found in previous attempts and is likely unavailable.
print("Acknowledgement: The weather data file 'OBS_ASOS_TIM_20251030122242.xls' was not found in previous attempts and is likely unavailable.")
print("Therefore, merging with weather data as originally intended is not possible.")

# 2. Examine the df_vegetable DataFrame to see if there is a time-series component or columns that can be used for forecasting within this dataset alone.
print("\nExamining the vegetable production DataFrame (df_vegetable) for time-series components:")
display(df_vegetable.head())
display(df_vegetable.info())

# Based on the df_vegetable structure (after fixing headers):
# Columns are like 'Metric_Year' (e.g., '조미채소:면적 (ha)_2025').
# Rows represent '시도별' (regions).
# This dataset contains production and area data for various vegetables for the year 2025, aggregated by region.
# It does not contain historical data over time for '일조(hr)' (sunshine hours) or any other weather-related time series.
# It is a snapshot of vegetable production for 2025, not a time series suitable for forecasting weather variables like '일조(hr)'.

# 3. If a time-series component suitable for forecasting '일조(hr)' (sunshine hours) is identified within df_vegetable (which is unlikely given its content based on previous inspection), proceed to the next relevant forecasting step using df_vegetable.
print("\nChecking if df_vegetable contains data relevant to forecasting '일조(hr)':")
if '일조(hr)' in df_vegetable.columns or any('일조(hr)' in col for col in df_vegetable.columns):
    print("df_vegetable contains '일조(hr)' data or related columns.")
    # Although highly unlikely based on the data description,
    # if it somehow contained time-series '일조(hr)' data, the next step would be forecasting.
    # Since it doesn't, this block is skipped.
else:
    print("df_vegetable does NOT contain data relevant to forecasting '일조(hr)'.")

# 4. If df_vegetable does not contain data relevant to forecasting '일조(hr)' and the merge with weather data is essential for the task's goal, report that the task cannot be completed due to the missing weather data.
print("\nConclusion:")
print("The vegetable production data (df_vegetable) does not contain time-series data for '일조(hr)'.")
print("The original task requires merging with weather data (which contains '일조(hr)') to perform the forecast.")
print("Since the weather data file is unavailable, the task cannot be completed as intended.")
# Out:
# Acknowledgement: The weather data file 'OBS_ASOS_TIM_20251030122242.xls' was not found in previous attempts and is likely unavailable.
# Therefore, merging with weather data as originally intended is not possible.
#
# Examining the vegetable production DataFrame (df_vegetable) for time-series components:
#     시도별          2025        2025.1      2025.2      2025.3       2025.4  \
# 0   시도별  조미채소:면적 (ha)  조미채소:생산량 (톤)  고추:면적 (ha)  고추:생산량 (톤)  건고추:면적 (ha)
# 1  충청북도             -             -           -           -            -
# 2  충청남도             -             -           -           -            -
# 3   제주도             -             -           -           -            -
# 4  전라북도             -             -           -           -            -
#
#               2025.5       2025.6       2025.7             2025.8  ...  \
# 0  건고추:10a당 생산량 (kg)  건고추:생산량 (톤)  풋고추:면적 (ha)  풋고추:10a당 생산량 (kg)  ...
# 1                  -            -            -                  -  ...
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The task aimed to merge vegetable production data with weather data and forecast sunshine hours ('일조(hr)').
# *   The vegetable production data (`df_vegetable`) was successfully loaded but is structured as a cross-sectional dataset for the year 2025, containing production and area metrics by region. It does not contain time-series data for weather variables.
# *   Multiple attempts to load the weather data file (`/content/OBS_ASOS_TIM_20251030122242.xls`) failed because the file was not found in the specified directory.
# *   Without the weather data, which contains the '일조(hr)' time series, merging the datasets and performing the requested forecast is impossible.
#
# ### Insights or Next Steps
#
# *   The task cannot be completed as originally specified due to the unavailability of the weather data file.
# *   To proceed, the weather data file containing '일조(hr)' time series would need to be provided.
